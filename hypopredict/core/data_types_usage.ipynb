# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
! pip freeze | grep hypopredict
# Out:
# -e git+https://github.com/sasha17demin/hypopredict.git@91de80467b86b30201d9e195bb379659db18803f#egg=hypopredict

# %%
from hypopredict import PersonDay

# %%
id = PersonDay(person_id=7, day=1)

# %%
id
# Out:
# PersonDay(person_id=7, day=1)

# %%
print(id)
# Out:
# Person7_Day1

# %%
id.to_legacy_id()
# Out:
# 71

# %%
PersonDay.from_legacy_id(71)
# Out:
# PersonDay(person_id=7, day=1)

# %%
# immutable
id.person_id = 10  # raises error
# Out:
# ---------------------------------------------------------------------------
# FrozenInstanceError                       Traceback (most recent call last)
# Cell In[13], line 2
#       1 # immutable
# ----> 2 id.person_id = 10  # raises error
#
# File <string>:4, in __setattr__(self, name, value)
#
# FrozenInstanceError: cannot assign to field 'person_id'
